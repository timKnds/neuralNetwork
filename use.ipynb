# %%
from Activation import *
from Loss import MSE, CrossEntropy
from Layer import FCLayer, ActivationLayer
from Network import *
import numpy as np

# %%
x_train = np.array([[[0, 0]], [[0, 1]], [[1, 0]], [[1, 1]]])
y_train = np.array([[[0]], [[1]], [[1]], [[0]]])

# %%
nn = Network()
nn.add(FCLayer(2, 3))
nn.add(ActivationLayer(Tanh()))
nn.add(FCLayer(3, 1))
nn.add(ActivationLayer(Tanh()))
nn.use(MSE())

# %%
nn.fit(x_train, y_train, epochs=10000, learning_rate=0.1)
# Out:
# epoch 1/10000  error=0.456362
# epoch 2/10000  error=0.567305
# epoch 3/10000  error=0.591497
# epoch 4/10000  error=0.593542
# epoch 5/10000  error=0.589513
# epoch 6/10000  error=0.583339
# epoch 7/10000  error=0.575899
# epoch 8/10000  error=0.567296
# epoch 9/10000  error=0.557427
# epoch 10/10000  error=0.546135
# epoch 11/10000  error=0.533258
# epoch 12/10000  error=0.518661
# epoch 13/10000  error=0.502278
# epoch 14/10000  error=0.484156
# epoch 15/10000  error=0.464507
# epoch 16/10000  error=0.443735
# epoch 17/10000  error=0.422425
# epoch 18/10000  error=0.401274
# epoch 19/10000  error=0.380998
# epoch 20/10000  error=0.362253
# epoch 21/10000  error=0.345678
# epoch 22/10000  error=0.332215
# epoch 23/10000  error=0.324242
# epoch 24/10000  error=0.330736
# epoch 25/10000  error=0.405940
# epoch 26/10000  error=0.887002
# epoch 27/10000  error=2.064948
# epoch 28/10000  error=2.812576
# epoch 29/10000  error=3.085651
# epoch 30/10000  error=3.188819
# ...

# %%
nn([1, 0])
# Out:
# array([[-0.99999419]])

# %%
num = 1
tanh = Tanh.activ(num)
print(tanh)
# Out:
# 0.7615941559557649

# %%
Tanh.activ_grad(num)
# Out:
# 0.41997434161402614

# %%
xs = np.array([[1, 0]])
ys = [[1]]

# %%
first_layer = FCLayer(2, 1)
output_fl = first_layer(xs)
sec_layer = ActivationLayer(Tanh())
output = sec_layer(output_fl)
print(output)
# Out:
# [[-0.80250675]]

# %%
xs = np.array([[1, 0], [0, 1], [1, 1]])
ys = np.array([[1], [1], [0]])

# %%
layers = [FCLayer(2, 1), ActivationLayer(Tanh())]
res = []
for xi in xs:
    output = xi
    for layer in layers:
        output = layer(output)
    res.append(output)
print(res)
# Out:
# [array([[0.86833785]]), array([[-0.10521699]]), array([[0.40916865]])]

# %%
epochs = 100
for i in range(epochs):
    for xi, yi in zip(xs, ys):
    # forward
        output = xi
        for layer in layers:
            output = layer(output)
        print('loss: ', MSE().loss(yi, output))
        err_grad = MSE().loss_grad(yi, output)
        for layer in reversed(layers):
            err_grad = layer.backward(err_grad, 0.1)
# Out:
# loss:  [[0.01733492]]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/timknudsen/Documents/Dokumente Mac/Pycharm-Projekte/neuralNetwork/use.ipynb Zelle 12 line 1
#       <a href='vscode-notebook-cell:/Users/timknudsen/Documents/Dokumente%20Mac/Pycharm-Projekte/neuralNetwork/use.ipynb#X40sZmlsZQ%3D%3D?line=8'>9</a> err_grad = MSE().loss_grad(yi, output)
#      <a href='vscode-notebook-cell:/Users/timknudsen/Documents/Dokumente%20Mac/Pycharm-Projekte/neuralNetwork/use.ipynb#X40sZmlsZQ%3D%3D?line=9'>10</a> for layer in reversed(layers):
# ---> <a href='vscode-notebook-cell:/Users/timknudsen/Documents/Dokumente%20Mac/Pycharm-Projekte/neuralNetwork/use.ipynb#X40sZmlsZQ%3D%3D?line=10'>11</a>     err_grad = layer.backward(err_grad, 0.1)
#
# File ~/Documents/Dokumente Mac/Pycharm-Projekte/neuralNetwork/Layer.py:36, in FCLayer.backward(self, output_error, learning_rate)
# ...
